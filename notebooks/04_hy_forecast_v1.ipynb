# %% [markdown]
# # Notebook 04 — HY forecast (BSTS)
#
# Fit BSTS with spike-and-slab on **HY** (HYG ETF, our proxy for HY OAS) using the full Trends predictor universe + macro controls. Inspect inclusion probabilities, component decomposition, and in-sample fit.
#
# *Run again after the topic-only re-pull completes to pick up the 20 newly-validated topics.*

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve()))
from _helpers import project_root_from_cwd, build_full_feature_matrix, fit_bsts_default
import matplotlib.pyplot as plt
import pandas as pd
project_root_from_cwd()
# Out:
# PosixPath('/Users/cesarebavaresco/Library/CloudStorage/OneDrive-TheUniversityofChicago/Project Lab/Neurberger Berman/Google Trends/gtrends-bayes')

# %% [markdown]
# ## 1. Build feature matrix for HY

# %%
art = build_full_feature_matrix('HY', apply_target_transform=False, include_controls=True)
X, y = art['X'], art['y']
print(f'HY target series:  {len(art["target_series"]):>4d} weekly bars cached')
print(f'Trends predictors: {art["processed"].shape[1]} after quality filter')
print(f'Aligned (X, y):    X={X.shape}, y={y.shape}, range {X.index.min().date()} .. {X.index.max().date()}')
print(f'Always-included macro controls: {art["control_names"]}')
print(f'(target = HYG ETF total-return price; positive Δy = spreads tightened)')
# Out:
# 2026-05-03 21:55:28,937 | WARNING | gtrends_bayes.features.library | dropping 1 low-quality columns (NaN frac > 0.50): ['Credit Cards']
# HY target series:   957 weekly bars cached
# Trends predictors: 21 after quality filter
# Aligned (X, y):    X=(487, 24), y=(487,), range 2009-01-04 .. 2026-04-26
# Always-included macro controls: ['vix', 'ust10y', 'ust2y10y_slope']
# (target = HYG ETF total-return price; positive Δy = spreads tightened)

# %% [markdown]
# ## 2. Fit BSTS

# %%
model = fit_bsts_default(y, X, niter=1500, burn=150, expected_predictors=5, seed=42)
print(model)
# Out:
# Error importing in API mode: ImportError("dlopen(/opt/anaconda3/lib/python3.13/site-packages/_rinterface_cffi_api.abi3.so, 0x0002): Library not loaded: /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib\n  Referenced from: <2F94BB47-26EE-3EB3-85C5-1EA8A83C71AB> /opt/anaconda3/lib/python3.13/site-packages/_rinterface_cffi_api.abi3.so\n  Reason: tried: '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file)")
# Trying to import in ABI mode.
# 2026-05-03 21:55:29,589 | INFO    | gtrends_bayes.models.bsts | rpy2 bridge initialized; R bsts helpers loaded from /Users/cesarebavaresco/Library/CloudStorage/OneDrive-TheUniversityofChicago/Project Lab/Neurberger Berman/Google Trends/gtrends-bayes/src/gtrends_bayes/models/bsts_r
# 2026-05-03 21:55:54,854 | INFO    | gtrends_bayes.models.bsts | BSTS fit done (model_id=bsts_009421a9, niter=1500, burn=150, p=24, has_regression=True)
# BSTS(n_seasons=52, expected_predictors=5, niter=1500, burn=150, seed=42, fitted=True, has_regression=True)

# %% [markdown]
# ## 3. Posterior inclusion probabilities (top 20)

# %%
probs = model.inclusion_probabilities()
top = probs.head(20)
fig, ax = plt.subplots(figsize=(9, 7))
top.plot.barh(ax=ax, color='steelblue')
ax.set_title('Posterior inclusion probability — HY (HYG ETF)\nTop 20 predictors')
ax.invert_yaxis()
ax.set_xlim(0, 1)
ax.set_xlabel('P(predictor included)')
ax.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()
print(probs.round(3).to_string())
# Out:
# Economic crisis            1.000
# vix                        0.408
# Bankruptcy                 0.057
# Foreclosure                0.021
# Home Financing             0.020
# Agriculture & Forestry     0.018
# ust2y10y_slope             0.016
# Apparel                    0.014
# Autos & Vehicles           0.013
# Investing                  0.010
# Jobs                       0.007
# Food & Drink               0.007
# Energy & Utilities         0.006
# Manufacturing              0.006
# Job Listings               0.005
# Insurance                  0.004
# Finance                    0.003
# Real Estate                0.003
# Recruitment & Staffing     0.003
# Auto Financing             0.002
# ust10y                     0.002
# Hotels & Accommodations    0.002
# Credit & Lending           0.001
# Travel                     0.001

# %% [markdown]
# ## 4. Coefficient summary (sign + magnitude when included)

# %%
summary = model.coefficient_summary().round(4)
summary.head(20)
# Out:
#                         inclusion_prob  mean_when_included  sd_when_included  \
# predictor
# Economic crisis                 1.0000             -0.2914            0.0459
# vix                             0.4081             -0.8773            0.2719
# Bankruptcy                      0.0570             -0.3651            0.0997
# Foreclosure                     0.0207             -0.2492            0.1442
# Home Financing                  0.0200              1.3558            1.0171
# Agriculture & Forestry          0.0178             -0.8145            0.7920
# ust2y10y_slope                  0.0156             -0.0466            0.0432
# Apparel                         0.0141             -0.3381            0.3032
# Autos & Vehicles                0.0133             -0.3745            0.2843
# Investing                       0.0096              0.1363            0.1302
# Jobs                            0.0074              0.0519            0.1653
# Food & Drink                    0.0067             -0.1263            0.3053
# Energy & Utilities              0.0059             -0.0525            0.2437
# Manufacturing                   0.0059             -0.0148            0.1161
# Job Listings                    0.0052              0.1298            0.1568
# Insurance                       0.0037              0.1066            0.0639
# Finance                         0.0030              0.0555            0.1007
# Real Estate                     0.0030              0.1985            0.2004
# Recruitment & Staffing          0.0030              0.0889            0.0790
# Auto Financing                  0.0022              0.0232            0.0414
#
#                         sign_consistency
# predictor
# Economic crisis                   1.0000
# vix                               1.0000
# Bankruptcy                        1.0000
# Foreclosure                       0.9286
# Home Financing                    0.8889
# Agriculture & Forestry            0.8750
# ust2y10y_slope                    0.7619
# Apparel                           0.7895
# Autos & Vehicles                  0.9444
# Investing                         0.9231
# Jobs                              0.6000
# Food & Drink                      0.5556
# Energy & Utilities                0.5000
# Manufacturing                     0.3750
# Job Listings                      1.0000
# Insurance                         1.0000
# Finance                           0.7500
# Real Estate                       1.0000
# Recruitment & Staffing            0.7500
# Auto Financing                    0.6667

# %% [markdown]
# ## 5. State component bands (level / trend / seasonal / regression)

# %%
bands = model.component_bands(q_low=0.10, q_high=0.90)
fig, axes = plt.subplots(len(bands), 1, figsize=(11, 2.4 * len(bands)), sharex=True)
if len(bands) == 1:
    axes = [axes]
for ax, (name, df) in zip(axes, bands.items()):
    ax.fill_between(df.index, df['q_low'], df['q_high'], color='steelblue', alpha=0.25, label='80% band')
    ax.plot(df.index, df['q_med'], color='steelblue', lw=1.0, label='median')
    ax.set_title(f'{name}')
    ax.grid(alpha=0.3)
    ax.legend(loc='upper right', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. In-sample fit (observed HY vs BSTS-implied)

# %%
import numpy as np
# Sum of state contributions = BSTS in-sample fit
fit_components = sum(b['q_med'] for b in bands.values())
fig, ax = plt.subplots(figsize=(11, 4))
ax.plot(y.index, y.values, color='black', lw=1.0, label='HY (observed)')
ax.plot(fit_components.index, fit_components.values, color='steelblue', lw=1.0, label='BSTS in-sample fit')
resid = y - fit_components.reindex(y.index)
ax.set_title(f'HY observed vs BSTS in-sample fit  |  resid std={resid.std():.3f}')
ax.set_ylabel('HY (HYG ETF, total-return price)')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Persist artifacts so notebook 06 can load them

# %%
import pickle
out_dir = Path('data/processed/posterior')
out_dir.mkdir(parents=True, exist_ok=True)
artifact = {
    'target': 'HY',
    'inclusion_probs': probs,
    'coefficient_summary': summary,
    'component_bands': bands,
    'in_sample_fit_median': fit_components,
    'X_columns': list(X.columns),
    'y': y,
}
(out_dir / 'HY_bsts_v1.pkl').write_bytes(pickle.dumps(artifact))
print('wrote', out_dir / 'HY_bsts_v1.pkl')
# Free the R-side model copy.
from gtrends_bayes.models.bsts import reset_r_models
reset_r_models()
print('R-side BSTS registry cleared.')
# Out:
# wrote data/processed/posterior/HY_bsts_v1.pkl
# R-side BSTS registry cleared.
